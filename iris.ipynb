# %% [markdown]
# <a href="https://colab.research.google.com/github/jkabila/Airline-customer-segmentation/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
# create figure and axis
fig, ax=plt.subplots()
# scatter sepal length against sepal width
ax.scatter(df['sepal_length'],df["sepal_width"])

ax.set_title("Iris Dataset")
ax.set_xlabel("sepal length")
ax.set_ylabel("sepal width")
# Out:
# Text(0, 0.5, 'sepal width')

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
colors={'Iris-setosa':'r','Iris-versicolor':'b',"Iris-virginica":'g'}
fig,ax=plt.subplots()
for i in range(len(df['sepal_length'])):
  ax.scatter(df["sepal_length"][i],df["sepal_width"][i],color=colors[df['species'][i]])
ax.set_label("Iris dataset")
ax.set_xlabel("sepal length")
ax.set_ylabel('sepal width')
# Out:
# Text(0, 0.5, 'sepal width')

# %%
# create figure and axis
fig, ax=plt.subplots()
# scatter sepal length against sepal width
ax.scatter(df['petal_length'],df["petal_width"])

ax.set_title("Iris Dataset")
ax.set_xlabel("petal length")
ax.set_ylabel("petal width")
# Out:
# Text(0, 0.5, 'petal width')

# %%
colors={'Iris-setosa':'r','Iris-versicolor':'b',"Iris-virginica":'g'}
fig,ax=plt.subplots()
for i in range(len(df["petal_length"])):
  ax.scatter(df["petal_length"][i],df["petal_width"][i],color=colors[df['species'][i]])
ax.set_label("Iris dataset")
ax.set_xlabel("Petal length")
ax.set_ylabel("Petal width")
# Out:
# Text(0, 0.5, 'Petal width')

# %%
# petal length and petal width has a linear relationship

# %%
columns=df.columns.drop(["species"])
x_data=range(0,df.shape[0])
fig,ax=plt.subplots()
for column in columns:
  ax.plot(x_data,df[column],label=column)
ax.set_label("Iris Dataset")
ax.legend()

# %%
# distribition of features and target
col='sepal_length'
df[col].hist()
plt.suptitle(col)
plt.show()

# %%
col="sepal_width"
df[col].hist()
plt.suptitle(col)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#col=["sepal_width","petal_length","petal_width"]
#for i in range(len(col)):
#  df[col].hist()
#plt.show()

# %%
col="petal_length"
df[col].hist()
plt.suptitle(col)
plt.show()

# %%
col="petal_width"
df[col].hist()
plt.suptitle(col)
plt.show()

# %%
col="sepal_length"
sns.relplot(x=col,y="species",hue="species",data=df)

# %%
col="sepal_width"
sns.relplot(x=col,y="species",hue="species",data=df)

# %%
col="petal_length"
sns.relplot(x=col,y="species",hue="species",data=df)

# %%
col="petal_width"
sns.relplot(x=col,y="species",hue="species",data=df)

# %%
#pari plot
sns.pairplot(df,hue="species")
